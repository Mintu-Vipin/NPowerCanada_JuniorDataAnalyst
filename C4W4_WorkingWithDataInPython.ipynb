# %% [markdown]
# <a href="https://colab.research.google.com/github/Mintu-Vipin/NPowerCanada/blob/main/C4W4_WorkingWithDataInPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = open("Text.txt", "r")
print(text.read())
# Out:
# Line 1
#
# Line 2
#
# Line 3
#
# finished

# %%
text.close()

# %%
with open("Text.txt", "r") as text:
  print(text.read())
# Out:
# Line 1
#
# Line 2
#
# Line 3
#
# finished

# %%
text.mode
# Out:
# 'r'

# %%
text.name
# Out:
# 'Text.txt'

# %%
with open("Text.txt", "r") as text:
  print(text.read(2))
# Out:
# Li

# %%
print(text.read(2)) # Error bcause the file is closed(open using 'with')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-3223c3e443d3> in <cell line: 1>()
# ----> 1 print(text.read(2))
#
# ValueError: I/O operation on closed file.

# %%
text.close()

# %%
text = open("Text.txt", "r")
for i in text:
  print(text.read())
# Out:
# Line 2
#
# Line 3
#
# finished

# %%
#Write mode

f = open("Textwrite.txt", "w")
f.write("I used write mode")
f.close()

# %%
f = open("Textwrite.txt", "w")
f.write("Hello")
f.close()

#data will overwrite

# %%
#Append Mode

text = open("Textwrite.txt", "a")
text.write("\nAdding ")
text.close()

# %%
import pandas as pd
dataSet1 = [1,3,5,7]
dataSet2 = [2,4,6,8,10]

#Converting lists to pandas

series1 = pd.Series(dataSet1)
series2 = pd.Series(dataSet2)

series = series1+series2
series
# Out:
# 0     3.0
# 1     7.0
# 2    11.0
# 3    15.0
# 4     NaN
# dtype: float64

# %%
data = {'apples':[3, 2, 0, 1],
        'oranges':[0, 3, 7, 2]}
print(data)
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %%
purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index =['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.iloc[0]
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
matches = pd.read_csv("matches.csv")

print(matches)
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
matches = pd.read_csv("matches.csv", index_col= "season")
matches
# Out:
#            id           city        date                        team1  \
# season
# 2017        1      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2017        2           Pune  2017-04-06               Mumbai Indians
# 2017        3         Rajkot  2017-04-07                Gujarat Lions
# 2017        4         Indore  2017-04-08       Rising Pune Supergiant
# 2017        5      Bangalore  2017-04-08  Royal Challengers Bangalore
# ...       ...            ...         ...                          ...
# 2019    11347         Mumbai    05/05/19        Kolkata Knight Riders
# 2019    11412        Chennai    07/05/19          Chennai Super Kings
# 2019    11413  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 2019    11414  Visakhapatnam    10/05/19               Delhi Capitals
# 2019    11415      Hyderabad    12/05/19               Mumbai Indians
#
#                               team2                  toss_winner  \
# season
# ...

# %%
matches.head(5)
# Out:
#         id       city        date                        team1  \
# season
# 2017     1  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 2017     2       Pune  2017-04-06               Mumbai Indians
# 2017     3     Rajkot  2017-04-07                Gujarat Lions
# 2017     4     Indore  2017-04-08       Rising Pune Supergiant
# 2017     5  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                               team2                  toss_winner  \
# season
# 2017    Royal Challengers Bangalore  Royal Challengers Bangalore
# 2017         Rising Pune Supergiant       Rising Pune Supergiant
# 2017          Kolkata Knight Riders        Kolkata Knight Riders
# 2017                Kings XI Punjab              Kings XI Punjab
# 2017               Delhi Daredevils  Royal Challengers Bangalore
#
#        toss_decision  result  dl_applied                       winner  \
# season
# 2017           field  normal           0          Sunrisers Hyderabad
# ...

# %%
matches.tail(5)
# Out:
#            id           city      date                  team1  \
# season
# 2019    11347         Mumbai  05/05/19  Kolkata Knight Riders
# 2019    11412        Chennai  07/05/19    Chennai Super Kings
# 2019    11413  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 2019    11414  Visakhapatnam  10/05/19         Delhi Capitals
# 2019    11415      Hyderabad  12/05/19         Mumbai Indians
#
#                       team2          toss_winner toss_decision  result  \
# season
# 2019         Mumbai Indians       Mumbai Indians         field  normal
# 2019         Mumbai Indians  Chennai Super Kings           bat  normal
# 2019         Delhi Capitals       Delhi Capitals         field  normal
# 2019    Chennai Super Kings  Chennai Super Kings         field  normal
# 2019    Chennai Super Kings       Mumbai Indians           bat  normal
#
#         dl_applied               winner  win_by_runs  win_by_wickets  \
# season
# ...

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 2017 to 2019
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   city             749 non-null    object
#  2   date             756 non-null    object
#  3   team1            756 non-null    object
#  4   team2            756 non-null    object
#  5   toss_winner      756 non-null    object
#  6   toss_decision    756 non-null    object
#  7   result           756 non-null    object
#  8   dl_applied       756 non-null    int64
#  9   winner           752 non-null    object
#  10  win_by_runs      756 non-null    int64
#  11  win_by_wickets   756 non-null    int64
#  12  player_of_match  752 non-null    object
#  13  venue            756 non-null    object
#  14  umpire1          754 non-null    object
#  15  umpire2          754 non-null    object
# ...

# %%
matches.shape
# Out:
# (756, 17)

# %%
temp_df = matches.append(matches)
temp_df.shape
# Out:
# <ipython-input-113-92594c006e5f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = matches.append(matches)
# (1512, 17)

# %%
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (756, 17)

# %%
from bs4 import BeautifulSoup
