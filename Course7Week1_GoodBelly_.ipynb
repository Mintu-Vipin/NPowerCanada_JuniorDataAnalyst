# %% [markdown]
# <a href="https://colab.research.google.com/github/Mintu-Vipin/NPowerCanada_JuniorDataAnalyst/blob/main/Course7Week1_GoodBelly_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
path='GoodBelly-DataSet.xlsx'
df=pd.read_excel(path, sheet_name = 'Real Data')
df.head()
# Out:
#         Date Region                    Store  Units Sold  \
# 0 2010-05-04     FL  Biscayne (aka Aventura)  150.702088
# 1 2010-05-11     FL  Biscayne (aka Aventura)  197.403797
# 2 2010-05-18     FL  Biscayne (aka Aventura)  235.106172
# 3 2010-05-25     FL  Biscayne (aka Aventura)  226.692427
# 4 2010-06-01     FL  Biscayne (aka Aventura)  257.688151
#
#    Average Retail Price  Sales Rep  Endcap  Demo  Demo1-3  Demo4-5  Natural  \
# 0              4.390000          0       0     0        0        0        1
# 1              3.997692          0       0     0        0        0        1
# 2              3.809231          0       0     0        0        0        1
# 3              3.835000          0       0     0        0        0        1
# 4              3.902500          0       0     0        0        0        1
#
#    Fitness
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
#Q1 - Give summary of numeric type of columns in dataset?
df.describe()
# Out:
#         Units Sold  Average Retail Price    Sales Rep       Endcap  \
# count  1386.000000           1386.000000  1386.000000  1386.000000
# mean    253.820718              4.107093     0.549784     0.038240
# std     110.998731              0.463828     0.497695     0.191843
# min      47.559852              2.889286     0.000000     0.000000
# 25%     189.995471              3.775714     0.000000     0.000000
# 50%     236.735266              4.096667     1.000000     0.000000
# 75%     295.804391              4.425067     1.000000     0.000000
# max    1041.200256              6.251538     1.000000     1.000000
#
#               Demo      Demo1-3      Demo4-5      Natural      Fitness
# count  1386.000000  1386.000000  1386.000000  1386.000000  1386.000000
# mean      0.058442     0.156566     0.075758     1.448773     2.476190
# std       0.234661     0.363522     0.264705     0.975092     1.592789
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
#Q2 Calc STD of columns in dataset
df.std()
# Out:
# <ipython-input-8-ccc11ca4c782>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Date                    22 days 03:27:15.853934319
# Units Sold                              110.998731
# Average Retail Price                      0.463828
# Sales Rep                                 0.497695
# Endcap                                    0.191843
# Demo                                      0.234661
# Demo1-3                                   0.363522
# Demo4-5                                   0.264705
# Natural                                   0.975092
# Fitness                                   1.592789
# dtype: object

# %%
#Q3 mean of first 50 records in dataset
df.head(50).mean()
# Out:
# <ipython-input-26-2a77d0f719a1>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.head(50).mean()
# <ipython-input-26-2a77d0f719a1>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.head(50).mean()
# Units Sold              186.280727
# Average Retail Price      4.128036
# Sales Rep                 0.000000
# Endcap                    0.100000
# Demo                      0.000000
# Demo1-3                   0.000000
# Demo4-5                   0.040000
# Natural                   1.300000
# Fitness                   1.560000
# dtype: float64

# %%
#Q4 What are the column names
df.columns
# Out:
# Index(['Date', 'Region', 'Store', 'Units Sold', 'Average Retail Price',
#        'Sales Rep', 'Endcap', 'Demo', 'Demo1-3', 'Demo4-5', 'Natural',
#        'Fitness'],
#       dtype='object')

# %%
#Q - Number of elements in dataset

df.size
# Out:
# 16632

# %%
#Q- No. of records this dataset has
df.shape[0]
# Out:
# 1386

# %%
#Q type of column dataset has
df.dtypes
# Out:
# Date                    datetime64[ns]
# Region                          object
# Store                           object
# Units Sold                     float64
# Average Retail Price           float64
# Sales Rep                        int64
# Endcap                           int64
# Demo                             int64
# Demo1-3                          int64
# Demo4-5                          int64
# Natural                          int64
# Fitness                          int64
# dtype: object
